# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-smith-uwec/NLP_Spring2025/blob/main/Basic%20Text%20Normalization%20and%20Counting-Part%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import corpus from Project Gutenberg
#
# Strip header and footer
#
# Put in lowercase
#
# Remove stopwords
#
# wordclouds
#
# long words
#
# hapaxes
#
# lexical dispersion plot
#
# Zipf's Law

# %% [markdown]
# # Import a corpus from [Project Gutenberg](https://www.gutenberg.org/)

# %%
import requests

# Fetch book (Plain Text UTF-8)
url = "https://www.gutenberg.org/cache/epub/74409/pg74409.txt"
url = "https://www.gutenberg.org/cache/epub/70432/pg70432.txt"#Dorthy Sayers, Clouds of Witness
response = requests.get(url)
text = response.text

print(text[:500])
# Out:
# ﻿The Project Gutenberg eBook of Clouds of witness
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this e

# %%
# Strip headers and footers
start_index = text.find("*** START OF THE PROJECT GUTENBERG EBOOK CLOUDS OF WITNESS ***")
end_index = text.find("*** END OF THE PROJECT GUTENBERG EBOOK CLOUDS OF WITNESS ***")
corpus = text[start_index:end_index]

# Display first 500 characters
print(corpus[:500])
# Out:
# *** START OF THE PROJECT GUTENBERG EBOOK CLOUDS OF WITNESS ***
#
#
#
#
#
#                            Clouds of Witness
#
#                            DOROTHY L. SAYERS
#
#    Copyright 1927 by The Dial Press, Inc. This edition contains the
#                   complete text of the original book.
#
#
#                             THE SOLUTION OF
#                         THE RIDDLESDALE MYSTERY
#                                  WITH
#                                A REPORT

# %%
print(corpus[800:850])
# Out:
# ed style, has even less end than
# most of them. Bu

# %% [markdown]
# # Word Clouds

# %%
import nltk
import numpy as np
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.draw.dispersion import dispersion_plot
from nltk.probability import FreqDist
from collections import Counter
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
# Download NLTK resources
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Tokenize the corpus into words
words = word_tokenize(corpus.lower())

# Remove punctuation and stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalnum() and word not in stop_words]

# Count word frequencies
word_counts = Counter(filtered_words)

# Display the most common words
print("Most common words:")
for word, count in word_counts.most_common(10):
    print(f"{word}: {count}")

# Perform additional analysis
total_words = len(filtered_words)
unique_words = len(word_counts)
lexical_diversity = unique_words / total_words

print("\nCorpus Analysis:")
print(f"Total words: {total_words}")
print(f"Unique words: {unique_words}")
print(f"Lexical diversity (unique/total): {lexical_diversity:.2f}")
# Out:
# Most common words:
# said: 759
# peter: 366
# lord: 359
# parker: 268
# man: 245
# know: 239
# cathcart: 235
# well: 219
# one: 216
# mary: 209
#
# Corpus Analysis:
# Total words: 40035
# Unique words: 7952
# Lexical diversity (unique/total): 0.20

# %%
filtered_words[2000:2020]
# Out:
# ['jury',
#  'roomy',
#  'house',
#  'built',
#  'plain',
#  'style',
#  'leased',
#  'present',
#  'owner',
#  'walter',
#  'montague',
#  'lord',
#  'denver',
#  'season',
#  'montague',
#  'states',
#  'witness',
#  'resuming',
#  'got',
#  'conservatory']

# %%
print(f"Number of words before removing stop words and non-alpha: {len(words)}")
print(f"Number of words after removing stop words and non-alpha (filtered_words)={len(filtered_words)}")
# Out:
# Number of words before removing stop words and non-alpha: 107012
# Number of words after removing stop words and non-alpha (filtered_words)=40035

# %%
all_fd=nltk.FreqDist(words)
filtered_fd=nltk.FreqDist(filtered_words)

# %%
wordcloud_all = WordCloud(width = 1000, height = 800,
                      background_color ='white',
                      max_words=200,
                      prefer_horizontal=0.5,
                      # random_state=4,
                      contour_color='steelblue').generate_from_frequencies(all_fd)

wordcloud_filtered = WordCloud(width = 1000, height = 800,
                      background_color ='white',
                      max_words=200,
                      prefer_horizontal=0.5,
                      # random_state=4,
                      contour_color='steelblue').generate_from_frequencies(filtered_fd)

# %%
# plot the WordCloud image: all words
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud_all)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.title("STUPID Word Cloud\n",fontsize=24)
plt.show()

# %%
# plot the WordCloud image: filtered
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud_filtered)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.title("Smarter Word Cloud\n",fontsize=24)
plt.show()

# %% [markdown]
# # Lexical Dispersion Plot

# %%
top_words = [word for (word, freq) in all_fd.most_common(10)]
print(top_words)

top_words_filtered = [word for (word, freq) in filtered_fd.most_common(20)]
print(top_words_filtered)
# Out:
# [',', '.', 'the', "''", '``', 'and', 'to', 'of', 'a', 'i']
# ['said', 'peter', 'lord', 'parker', 'man', 'know', 'cathcart', 'well', 'one', 'mary', 'think', 'would', 'say', 'could', 'wimsey', 'like', 'sir', 'bunter', 'see', 'duke']

# %%
filtered_fd.most_common(20)
# Out:
# [('said', 759),
#  ('peter', 366),
#  ('lord', 359),
#  ('parker', 268),
#  ('man', 245),
#  ('know', 239),
#  ('cathcart', 235),
#  ('well', 219),
#  ('one', 216),
#  ('mary', 209),
#  ('think', 193),
#  ('would', 192),
#  ('say', 178),
#  ('could', 174),
#  ('wimsey', 169),
#  ('like', 169),
#  ('sir', 161),
#  ('bunter', 153),
#  ('see', 152),
#  ('duke', 151)]

# %%
plt.figure(figsize=(12, 9))
dispersion_plot(words, top_words_filtered, ignore_case=True, title='Lexical Dispersion Plot for Top 20 Words')
plt.show()

# %%
single_words = filtered_fd.hapaxes()
print(f"number of hapaxes={len(single_words)}")

import random
random.choice(single_words)
# Out:
# number of hapaxes=4058
# 'salutary'

# %%
V = set(filtered_words)
long_words = [w for w in V if len(w) > 14]

long_words
# Out:
# ['infailliblement',
#  'subconsciousness',
#  'undistinguished',
#  'sympathetically',
#  'misunderstanding',
#  'personification',
#  'notwithstanding',
#  'cinematographic',
#  'representatives',
#  'conscientiously',
#  'inconveniencing',
#  'heartbreakingly',
#  'extraordinarily',
#  'disillusionment',
#  'congratulations']

# %%
plt.figure(figsize=(12, 9))
dispersion_plot(words, long_words, ignore_case=True, title='Lexical Dispersion Plot for long words')
plt.show()

# %% [markdown]
# # [Zipf's Law](https://en.wikipedia.org/wiki/Zipf%27s_law)

# %%
words[100:120]
# Out:
# ['permeated',
#  'with',
#  'the',
#  'odour',
#  'of',
#  'joss-sticks',
#  'and',
#  'honourable',
#  'high-mindedness',
#  ',',
#  'and',
#  'the',
#  'two',
#  'characters',
#  'are',
#  'both',
#  'of',
#  'noble',
#  'birth._',
#  'the']

# %%
cleaned_tokens=[word for word in words if word.isalpha()]

# %%
cleaned_tokens[2000:2020]
# Out:
# ['he',
#  'lived',
#  'by',
#  'cheatin',
#  'at',
#  'cards',
#  'said',
#  'he',
#  'could',
#  'swear',
#  'to',
#  'it',
#  'with',
#  'details',
#  'of',
#  'a',
#  'row',
#  'there',
#  'been',
#  'in']

# %%
fdist = FreqDist(cleaned_tokens)
sorted_freqs = fdist.most_common()

sorted_freqs[0:10]
# Out:
# [('the', 4358),
#  ('and', 2210),
#  ('to', 2048),
#  ('of', 2006),
#  ('a', 1973),
#  ('i', 1843),
#  ('he', 1278),
#  ('it', 1266),
#  ('in', 1248),
#  ('you', 1215)]

# %%
word_frequencies = Counter(cleaned_tokens)
sorted_frequencies = sorted(word_frequencies.values(), reverse=True)

# Create an array of ranks (1, 2, 3, ...)
ranks = np.arange(1, len(sorted_freqs) + 1)

# %%
plt.figure(figsize=(10, 6))
plt.plot(ranks, sorted_frequencies, marker='.', linestyle='None')
plt.title("Zipf's Law Distribution")
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Plot the data on a log-log scale
plt.figure(figsize=(10, 6))
plt.loglog(ranks, sorted_frequencies, marker='.', linestyle='None')
plt.title("Zipf's Law Distribution")
plt.xlabel("Rank (log scale)")
plt.ylabel("Frequency (log scale)")
plt.grid(True)
plt.show()

# %%
from scipy.stats import linregress

# Assuming you have already calculated ranks and sorted_frequencies as mentioned earlier
log_ranks = np.log(ranks)
log_frequencies = np.log(sorted_frequencies)

# Fit a linear regression model to the log-log data
slope, intercept, r_value, p_value, std_err = linregress(log_ranks, log_frequencies)

# The slope of the regression line represents the estimated exponent 's'
estimated_s = -slope

print(f"Estimated exponent 's' in Zipf's Law: {estimated_s}")
# Out:
# Estimated exponent 's' in Zipf's Law: 1.1257483591609043
